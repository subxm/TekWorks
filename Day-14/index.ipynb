# %% [markdown]
# # ML Introduction

# %% [markdown]
# ### 1. Why we need to learn ML
# #### -
# ### 2. What is ML and how it works
# #### - ML is a technique in which a model is trained on the existing data and identify patterns and perform those on the new dataset.

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\subham\Desktop\TekWorks\Day-14\dataset.csv')
data
# Out:
#    Age  InsuranceCost
# 0   22           2500
# 1   25           2800
# 2   28           3200
# 3   30           3500
# 4   35           4200
# 5   40           5000
# 6   45           5800
# 7   50           6500
# 8   55           7200
# 9   60           8000

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Age'], data['InsuranceCost'])

# %%
# using numpy
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(data['Age'], data['InsuranceCost'])
m, c = np.polyfit(data['Age'], data['InsuranceCost'], 1)
plt.plot(data['Age'], m*data['Age'] + c, color='red')

# %%
# using seaborn
import seaborn as sns
sns.regplot(x='Age', y='InsuranceCost', data=data)
# Out:
# <Axes: xlabel='Age', ylabel='InsuranceCost'>

# %%
from sklearn.model_selection import train_test_split
x=data['Age']
y=data['InsuranceCost']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
x_train, x_test, y_train, y_test
# Out:
# (3    30
#  5    40
#  1    25
#  6    45
#  4    35
#  8    55
#  9    60
#  0    22
#  Name: Age, dtype: int64,
#  7    50
#  2    28
#  Name: Age, dtype: int64,
#  3    3500
#  5    5000
#  1    2800
#  6    5800
#  4    4200
#  8    7200
#  9    8000
#  0    2500
#  Name: InsuranceCost, dtype: int64,
#  7    6500
#  2    3200
#  Name: InsuranceCost, dtype: int64)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

x = x.to_numpy().reshape(-1, 1)
model.fit(x, y)
# Out:
# LinearRegression()
