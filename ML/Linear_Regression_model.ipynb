# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# ## 1. Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Import the Dataset

# %%
data = pd.read_csv(r'C:\Users\subham\Desktop\TekWorks\ML\linear_regression_datasest.csv')

# %%
data.head()
# Out:
#    Feature_1  Feature_2      Target
# 0  18.727006  26.661964   75.032045
# 1  47.535715  58.771085  186.095787
# 2  36.599697  88.565125  200.512604
# 3  29.932924  75.900240  174.586253
# 4   7.800932  82.590503  132.746780

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Feature_1  1000 non-null   float64
#  1   Feature_2  1000 non-null   float64
#  2   Target     1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %% [markdown]
# ## 3. Data Preprocessing

# %%
data.describe()
# Out:
#          Feature_1    Feature_2       Target
# count  1000.000000  1000.000000  1000.000000
# mean     24.512828    55.631557   133.169216
# std      14.606868    26.297090    49.845584
# min       0.231601    10.289644    11.866554
# 25%      11.798663    31.696684    97.734249
# 50%      24.840369    56.686052   134.027666
# 75%      37.215979    78.441855   169.051039
# max      49.985884    99.947235   255.915972

# %%
# Check for outliers using boxplot
plt.figure(figsize=(5, 5))
sns.boxplot(data=data)
plt.title('Boxplot for Outlier Detection')
plt.xlabel('Features')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ## 4. EDA

# %%
# Plot a scatter plot to visualize the relationship between the feature_1 and the target variable
plt.scatter(data['Feature_1'], data['Target'])
plt.xlabel('Feature 1')
plt.ylabel('Target Variable')
plt.title('Scatter Plot of Feature 1 vs Target Variable')
plt.show()

# %%
# Plot a scatter plot to visualize the relationship between the feature_2 and the target variable
plt.scatter(data['Feature_2'], data['Target'], color='orange')
plt.xlabel('Feature 2')
plt.ylabel('Target Variable')
plt.title('Scatter Plot of Feature 2 vs Target Variable')
plt.show()

# %% [markdown]
# ## 5. Feature Engg.

# %%
# Divide the data into features and target variable
X = data[['Feature_1', 'Feature_2']]
y = data['Target']
