# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Dataset_1.csv')
data
# Out:
#     order_id customer_id  customer_age order_amount  order_date payment_mode  \
# 0    ORD1000         NaN           NaN        250.5  2023-01-15   Debit Card
# 1    ORD1001         NaN          18.0         1200  2023/03/10   Debit Card
# 2    ORD1002       CUST2          35.0          NaN         NaN          NaN
# 3    ORD1003      user_3          35.0         1200  2023-01-15         Cash
# 4    ORD1004      user_4          -3.0      3500.75  2023-01-15         CARD
# ..       ...         ...           ...          ...         ...          ...
# 995      NaN    user_995          -3.0      3500.75  15/02/2023          upi
# 996      NaN     CUST996          18.0          NaN  2023-01-15  Credit Card
# 997      NaN    user_997          50.0          NaN  2023/03/10         Cash
# 998  ORD1998         NaN          65.0         1200  2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN  15/02/2023   Debit Card
#
#           city delivery_days is_delivered
# 0          NaN             5         True
# 1          NaN             5          yes
# 2       Mumbai             7          yes
# 3          NaN         three        False
# 4          NaN         three          yes
# ..         ...           ...          ...
# 995     Mumbai             1         True
# 996  Hyderabad             2          yes
# 997      Delhi             1          NaN
# 998     Mumbai             2        False
# 999        NaN            -1         True
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## 1st-

# %%
mask = pd.to_numeric(data['order_amount'], errors='coerce').isna() & data['is_delivered'].astype(str).str.lower().isin(["true","yes"])
data[mask]
# Out:
#     order_id customer_id  customer_age order_amount  order_date payment_mode  \
# 2    ORD1002       CUST2          35.0          NaN         NaN          NaN
# 14   ORD1014      CUST14          25.0          NaN  2023/03/10          upi
# 17       NaN         NaN          -3.0          NaN  15/02/2023          upi
# 24   ORD1024      CUST24           NaN         ₹999     invalid  Credit Card
# 27       NaN         NaN          25.0         ₹999  2023-01-15          NaN
# ..       ...         ...           ...          ...         ...          ...
# 985  ORD1985     CUST985          35.0         ₹999  15/02/2023   Debit Card
# 987      NaN     CUST987          50.0          NaN  2023/03/10          NaN
# 990      NaN         NaN          25.0         ₹999  15/02/2023          upi
# 996      NaN     CUST996          18.0          NaN  2023-01-15  Credit Card
# 999      NaN    user_999         120.0          NaN  15/02/2023   Debit Card
#
#           city delivery_days is_delivered
# 2       Mumbai             7          yes
# 14       DELHI             5          yes
# 17   Hyderabad           NaN         True
# 24       DELHI             1          yes
# 27         NaN           NaN         True
# ..         ...           ...          ...
# 985     Mumbai             5         True
# 987  Bangalore           NaN          yes
# 990  Hyderabad         three         True
# 996  Hyderabad             2          yes
# 999        NaN            -1         True
#
# [177 rows x 9 columns]

# %% [markdown]
# ## 2nd- Convert order_date to datetime and find orders where delivery_days is negative after valid date conversion

# %%
data['order_date'] = pd.to_datetime(data['order_date'], errors='coerce', dayfirst=True)

data['delivery_days'] = pd.to_numeric(data['delivery_days'], errors='coerce')
ans = data['delivery_days'] < 0 & data['order_date'].notna()
data[ans]
# Out:
#     order_id customer_id  customer_age order_amount order_date payment_mode  \
# 9        NaN      user_9           NaN          NaN        NaT          UPI
# 11       NaN      CUST11          18.0      3500.75        NaT         Cash
# 35       NaN     user_35          50.0       499.99        NaT         Cash
# 47       NaN     user_47          25.0          NaN        NaT         Cash
# 49   ORD1049      CUST49         120.0      3500.75        NaT          NaN
# ..       ...         ...           ...          ...        ...          ...
# 936  ORD1936    user_936           NaN          NaN        NaT          UPI
# 937  ORD1937     CUST937          -3.0          NaN 2023-01-15   Debit Card
# 938  ORD1938    user_938          65.0        250.5        NaT          upi
# 945  ORD1945         NaN           NaN        250.5 2023-01-15          NaN
# 999      NaN    user_999         120.0          NaN        NaT   Debit Card
#
#           city  delivery_days is_delivered  delivery_days_numeric
# 9        Delhi           -1.0           no                   -1.0
# 11      Mumbai           -1.0        False                   -1.0
# 35       DELHI           -1.0          yes                   -1.0
# 47      Mumbai           -1.0          NaN                   -1.0
# 49   Hyderabad           -1.0        False                   -1.0
# ..         ...            ...          ...                    ...
# 936  Bangalore           -1.0           no                   -1.0
# 937     mumbai           -1.0          yes                   -1.0
# 938     mumbai           -1.0          NaN                   -1.0
# 945     mumbai           -1.0           no                   -1.0
# 999        NaN           -1.0         True                   -1.0
#
# [137 rows x 10 columns]

# %% [markdown]
# ## 3rd-Standardize payment_mode and calculate the percentage share of each per city

# %%
# Standardize payment_mode and calculate the percentage share of each per city

# Create a mapping for payment_mode codes to readable names if needed
payment_mode_map = {
    1: 'Cash',
    2: 'Card',
    3: 'UPI',
    4: 'Debit Card',
    5: 'Net Banking'
}

# Replace payment_mode codes with readable names if not already done
data['payment_mode_std'] = data['payment_mode'].map(payment_mode_map).fillna(data['payment_mode'])

# Drop rows where city or payment_mode is missing for accurate calculation
city_payment = data.dropna(subset=['city', 'payment_mode_std'])

# Calculate counts per city and payment_mode
counts = city_payment.groupby(['city', 'payment_mode_std']).size().reset_index(name='count')

# Calculate total orders per city
total_per_city = counts.groupby('city')['count'].transform('sum')

# Calculate percentage share
counts['percentage'] = (counts['count'] / total_per_city * 100).round(2)

counts
# Out:
#         city payment_mode_std  count  percentage
# 0  Bangalore             Cash    151       100.0
# 1      DELHI             Cash    141       100.0
# 2      Delhi             Cash    161       100.0
# 3  Hyderabad             Cash    141       100.0
# 4     Mumbai             Cash    145       100.0
# 5     mumbai             Cash    119       100.0

# %% [markdown]
# ## 4- Detect customers whose customer_age is invalid but have order amounts above the dataset median

# %%
data
# Out:
#     order_id customer_id  customer_age order_amount order_date  payment_mode  \
# 0    ORD1000         NaN           NaN        250.5 2023-01-15             1
# 1    ORD1001         NaN          18.0         1200        NaT             1
# 2    ORD1002       CUST2          35.0          NaN        NaT             1
# 3    ORD1003      user_3          35.0         1200 2023-01-15             1
# 4    ORD1004      user_4          -3.0      3500.75 2023-01-15             1
# ..       ...         ...           ...          ...        ...           ...
# 995      NaN    user_995          -3.0      3500.75        NaT             1
# 996      NaN     CUST996          18.0          NaN 2023-01-15             1
# 997      NaN    user_997          50.0          NaN        NaT             1
# 998  ORD1998         NaN          65.0         1200 2023-01-15             1
# 999      NaN    user_999         120.0          NaN        NaT             1
#
#           city  delivery_days is_delivered  delivery_days_numeric
# 0          NaN            5.0         True                    5.0
# 1          NaN            5.0          yes                    5.0
# 2       Mumbai            7.0          yes                    7.0
# 3          NaN            NaN        False                    NaN
# 4          NaN            NaN          yes                    NaN
# ..         ...            ...          ...                    ...
# 995     Mumbai            1.0         True                    1.0
# 996  Hyderabad            2.0          yes                    2.0
# 997      Delhi            1.0          NaN                    1.0
# 998     Mumbai            2.0        False                    2.0
# 999        NaN           -1.0         True                   -1.0
#
# [1000 rows x 10 columns]

# %%
invalid = (data['customer_age'] < 0) | (data['customer_age'] > 100)

order_amount_numeric = pd.to_numeric(data['order_amount'], errors='coerce')

median = order_amount_numeric.median()

result = data[invalid & (order_amount_numeric > median)]
result
# Out:
#     order_id customer_id  customer_age  order_amount order_date  payment_mode  \
# 4    ORD1004      user_4            -3       3500.75 2023-01-15             1
# 34   ORD1034         NaN           120       3500.75        NaT             1
# 49   ORD1049      CUST49           120       3500.75        NaT             1
# 53       NaN     user_53           120       3500.75        NaT             1
# 59       NaN         NaN            -3       3500.75        NaT             1
# ..       ...         ...           ...           ...        ...           ...
# 954      NaN    user_954           120       1200.00 2023-01-15             1
# 971  ORD1971         NaN           120       1200.00        NaT             1
# 988      NaN         NaN           120       3500.75        NaT             1
# 991      NaN         NaN            -3       3500.75        NaT             1
# 995      NaN    user_995            -3       3500.75        NaT             1
#
#           city  delivery_days is_delivered  delivery_days_numeric  \
# 4          NaN            NaN          yes                    NaN
# 34   Hyderabad            7.0         True                    7.0
# 49   Hyderabad           -1.0        False                   -1.0
# 53   Hyderabad            NaN          NaN                    NaN
# 59   Bangalore            NaN        False                    NaN
# ..         ...            ...          ...                    ...
# 954     mumbai            1.0          yes                    1.0
# 971      Delhi            NaN          NaN                    NaN
# 988  Bangalore            2.0          yes                    2.0
# 991  Hyderabad            1.0          yes                    1.0
# 995     Mumbai            1.0         True                    1.0
#
#     payment_mode_std
# 4               Cash
# 34              Cash
# 49              Cash
# 53              Cash
# 59              Cash
# ..               ...
# 954             Cash
# 971             Cash
# 988             Cash
# 991             Cash
# 995             Cash
#
# [63 rows x 11 columns]

# %% [markdown]
# ## 5- find duplicate customer_ids where the same customer placed orders in multiple cities.

# %%
unique_city = data.groupby('customer_id')['city'].nunique()

customer_order = unique_city[unique_city >= 1].reset_index()
customer_order
# Out:
#     customer_id  city
# 0       CUST108     1
# 1        CUST11     1
# 2       CUST111     1
# 3       CUST117     1
# 4       CUST119     1
# ..          ...   ...
# 408    user_959     1
# 409     user_97     1
# 410    user_977     1
# 411    user_995     1
# 412    user_997     1
#
# [413 rows x 2 columns]

# %% [markdown]
# ## 6- Create a flag for orders where delivery_days is missing but is_delivered is True

# %%
#missing or true -> true
#missing or false -> false
#true or true -> false
#false or false -> false

data['order_placed_status'] = data['delivery_days'].isna() & (data['is_delivered'].isin(['True', 'true', 'YES', 'Yes', 'yes']))
data.sample(30)
# Out:
#     order_id customer_id  customer_age  order_amount order_date  payment_mode  \
# 891      NaN     CUST891            35        499.99        NaT             1
# 544      NaN     CUST544            -3           NaN        NaT             1
# 36       NaN      CUST36            50        499.99        NaT             1
# 720  ORD1720         NaN            35       1200.00 2023-01-15             1
# 240      NaN    user_240            35        250.50        NaT             1
# 63       NaN         NaN            18       1200.00 2023-01-15             1
# 404  ORD1404         NaN            50        250.50        NaT             1
# 13       NaN      CUST13            35           NaN        NaT             1
# 632      NaN    user_632            35           NaN        NaT             1
# 384  ORD1384         NaN            35           NaN        NaT             1
# 731  ORD1731    user_731            35       3500.75        NaT             1
# 114      NaN         NaN           120           NaN        NaT             1
# 675  ORD1675    user_675            65       1200.00        NaT             1
# 990      NaN         NaN            25           NaN        NaT             1
# 390  ORD1390     CUST390            35        250.50        NaT             1
# 302      NaN         NaN            25           NaN 2023-01-15             1
# 735      NaN         NaN            35       3500.75 2023-01-15             1
# 508      NaN     CUST508           120       3500.75        NaT             1
# 260      NaN     CUST260            50           NaN 2023-01-15             1
# 551      NaN     CUST551            25       3500.75        NaT             1
# 977      NaN    user_977            65        250.50        NaT             1
# 224      NaN         NaN           120           NaN        NaT             1
# 460      NaN         NaN            35       3500.75        NaT             1
# 277      NaN         NaN            65           NaN        NaT             1
# 960      NaN         NaN            35           NaN        NaT             1
# 550      NaN    user_550            35       1200.00        NaT             1
# 446      NaN     CUST446            35        499.99        NaT             1
# 293  ORD1293     CUST293            18        250.50        NaT             1
# 128      NaN         NaN            -3       1200.00        NaT             1
# 930  ORD1930         NaN            35       1200.00        NaT             1
#
#           city  delivery_days is_delivered  delivery_days_numeric  \
# 891     Mumbai            NaN          yes                    NaN
# 544  Hyderabad            NaN          NaN                    NaN
# 36   Bangalore            7.0          NaN                    7.0
# 720        NaN           -1.0        False                   -1.0
# 240     mumbai            7.0           no                    7.0
# 63       Delhi            1.0          NaN                    1.0
# 404  Bangalore            NaN           no                    NaN
# 13      Mumbai            7.0        False                    7.0
# 632     Mumbai            7.0          yes                    7.0
# 384      Delhi            1.0          yes                    1.0
# 731      Delhi            1.0        False                    1.0
# 114      Delhi            5.0           no                    5.0
# 675  Bangalore           -1.0        False                   -1.0
# 990  Hyderabad            NaN         True                    NaN
# 390     Mumbai            5.0          NaN                    5.0
# 302  Hyderabad            NaN          NaN                    NaN
# 735  Bangalore            NaN         True                    NaN
# 508      Delhi            1.0        False                    1.0
# 260      DELHI            1.0        False                    1.0
# 551      Delhi            NaN          yes                    NaN
# 977  Bangalore            1.0           no                    1.0
# 224        NaN            5.0          yes                    5.0
# 460     Mumbai           -1.0          NaN                   -1.0
# 277     mumbai            NaN          NaN                    NaN
# 960        NaN            NaN        False                    NaN
# 550     Mumbai            7.0         True                    7.0
# 446      Delhi            1.0        False                    1.0
# 293      DELHI            7.0        False                    7.0
# 128     mumbai            NaN        False                    NaN
# 930      Delhi            1.0         True                    1.0
#
#     payment_mode_std  order_placed_status
# 891             Cash                 True
# 544             Cash                False
# 36              Cash                False
# 720             Cash                False
# 240             Cash                False
# 63              Cash                False
# 404             Cash                False
# 13              Cash                False
# 632             Cash                False
# 384             Cash                False
# 731             Cash                False
# 114             Cash                False
# 675             Cash                False
# 990             Cash                 True
# 390             Cash                False
# 302             Cash                False
# 735             Cash                 True
# 508             Cash                False
# 260             Cash                False
# 551             Cash                 True
# 977             Cash                False
# 224             Cash                False
# 460             Cash                False
# 277             Cash                False
# 960             Cash                False
# 550             Cash                False
# 446             Cash                False
# 293             Cash                False
# 128             Cash                False
# 930             Cash                False
